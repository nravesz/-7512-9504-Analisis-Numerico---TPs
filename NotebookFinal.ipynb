# %% [markdown]
# # Funciones continuas y con raíz única a las cuales se les calculará la raíz en el intervalo [0, 2] dadas en el enunciado del Trabajo Práctico:

# %% [markdown]
# $ f_{1}(x) = x^{2}-2 $
#
# $ f_{2}(x) = x^{5}-6.6x^{4}+5.12x^{3}+21.312x^{2}-38.016x+17.28 $
#
# $ f_{3}(x) = (x-1.5)e^{-4(x-1.5)^{2}} $

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import common
import metodosDeBusqueda as metodo
import funciones as f
from scipy import optimize

# %% [markdown]
# #### Configuraciones

# %%
pd.set_option("display.precision", 16)

# %% [markdown]
# #### Funciones

# %%
f1 = f.f1
f2 = f.f2
f3 = f.f3

# %% [markdown]
# (a) Graficar las funciones en el intervalo de interés

# %%
common.graficar_funcion(f1)
# Out:
# f1(x)

# %%
common.graficar_funcion(f2)
# Out:
# f2(x)

# %%
common.graficar_funcion(f3)
# Out:
# f3(x)

# %% [markdown]
# (b) Halle para cada una de ellas la raı́z en el intervalo indicado mediante los métodos vistos en
# clase (Bisección, Newton-Raphson, Newton-Raphson modificado, Secante). Use para todos los
# métodos como criterio de parada las siguientes cotas: 1 · 10 −5 , 1 · 10 −13 , para Newton-Raphson
# use semilla x 0 = 1.0, para secante use como semillas los extremos del intervalo.

# %% [markdown]
# ### $ f_{1}(x) $

# %% [markdown]
# #### Biseccion, tolerancia 1e-13

# %%
historial, errores = metodo.biseccion(f1, 1e-13, 0.0, 2.0)
df_b_f1=(common.crear_df_iteraciones(historial, errores, "biseccion"))
df_b_f1 = df_b_f1[:5].append(df_b_f1[-5:]).set_index('iteracion')
df_b_f1
# Out:
#                          raiz               error     metodo
# iteracion
# 1          1.0000000000000000  0.5000000000000000  biseccion
# 2          1.5000000000000000  0.2500000000000000  biseccion
# 3          1.2500000000000000  0.1250000000000000  biseccion
# 4          1.3750000000000000  0.0625000000000000  biseccion
# 5          1.4375000000000000  0.0312500000000000  biseccion
# 41         1.4142135623724243  0.0000000000004547  biseccion
# 42         1.4142135623728791  0.0000000000002274  biseccion
# 43         1.4142135623731065  0.0000000000001137  biseccion
# 44         1.4142135623729928  0.0000000000000568  biseccion
# 45         1.4142135623730496  0.0000000000000284  biseccion

# %% [markdown]
# Raiz encontrada:

# %%
df_b_f1.tail(1)
# Out:
#                          raiz               error     metodo
# iteracion
# 45         1.4142135623730496  0.0000000000000284  biseccion

# %% [markdown]
# #### Biseccion, tolerancia 1e-5

# %%
historial, errores = metodo.biseccion(f1, 1e-5, 0.0, 2.0)
df_b_f1=(common.crear_df_iteraciones(historial, errores, "biseccion"))
df_b_f1 = df_b_f1[:5].append(df_b_f1[-5:]).set_index('iteracion')
df_b_f1
# Out:
#                          raiz               error     metodo
# iteracion
# 1          1.0000000000000000  0.5000000000000000  biseccion
# 2          1.5000000000000000  0.2500000000000000  biseccion
# 3          1.2500000000000000  0.1250000000000000  biseccion
# 4          1.3750000000000000  0.0625000000000000  biseccion
# 5          1.4375000000000000  0.0312500000000000  biseccion
# 14         1.4141845703125000  0.0000610351562500  biseccion
# 15         1.4142456054687500  0.0000305175781250  biseccion
# 16         1.4142150878906250  0.0000152587890625  biseccion
# 17         1.4141998291015625  0.0000076293945312  biseccion
# 18         1.4142074584960938  0.0000038146972656  biseccion

# %% [markdown]
# Raiz encontrada:

# %%
df_b_f1.tail(1)
# Out:
#                          raiz               error     metodo
# iteracion
# 18         1.4142074584960938  0.0000038146972656  biseccion

# %% [markdown]
# #### Newton-Raphson, tolerancia 1e-13

# %%
historial, errores = metodo.newton_raphson(f1, 1e-13, 1.0)
df_nr_f1=(common.crear_df_iteraciones(historial, errores, "newton_raphson")).set_index('iteracion')
df_nr_f1
# Out:
#                          raiz               error          metodo
# iteracion
# 1          1.5000000000000000  0.5000000000000000  newton_raphson
# 2          1.4166666666666667  0.0833333333333333  newton_raphson
# 3          1.4142156862745099  0.0024509803921569  newton_raphson
# 4          1.4142135623746899  0.0000021238998200  newton_raphson
# 5          1.4142135623730951  0.0000000000015947  newton_raphson
# 6          1.4142135623730949  0.0000000000000002  newton_raphson

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_f1.tail(1)
# Out:
#                          raiz               error          metodo
# iteracion
# 6          1.4142135623730949  0.0000000000000002  newton_raphson

# %% [markdown]
# #### Newton-Raphson, tolerancia 1e-5

# %%
historial, errores = metodo.newton_raphson(f1, 1e-5, 1.0)
df_nr_f1=(common.crear_df_iteraciones(historial, errores, "newton_raphson")).set_index('iteracion')
df_nr_f1
# Out:
#                          raiz               error          metodo
# iteracion
# 1          1.5000000000000000  0.5000000000000000  newton_raphson
# 2          1.4166666666666667  0.0833333333333333  newton_raphson
# 3          1.4142156862745099  0.0024509803921569  newton_raphson
# 4          1.4142135623746899  0.0000021238998200  newton_raphson

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_f1.tail(1)
# Out:
#                          raiz             error          metodo
# iteracion
# 4          1.4142135623746899  0.00000212389982  newton_raphson

# %% [markdown]
# #### Newton-Raphson modificado, tolerancia 1e-13

# %%
historial, errores = metodo.newtonRaphsonMod(f1, 1e-13, 1.0)
df_nr_mod_f1=(common.crear_df_iteraciones(historial, errores, "newton_raphson_mod")).set_index('iteracion')
df_nr_mod_f1
# Out:
#                          raiz               error              metodo
# iteracion
# 1          1.3333333333333333  0.3333333333333333  newton_raphson_mod
# 2          1.4117647058823528  0.0784313725490196  newton_raphson_mod
# 3          1.4142114384748701  0.0024467325925173  newton_raphson_mod
# 4          1.4142135623715002  0.0000021238966301  newton_raphson_mod
# 5          1.4142135623730949  0.0000000000015947  newton_raphson_mod
# 6          1.4142135623730951  0.0000000000000002  newton_raphson_mod

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_mod_f1.tail(1)
# Out:
#                          raiz               error              metodo
# iteracion
# 6          1.4142135623730951  0.0000000000000002  newton_raphson_mod

# %% [markdown]
# #### Newton-Raphson modificado, tolerancia 1e-5

# %%
historial, errores = metodo.newtonRaphsonMod(f1, 1e-5, 1.0)
df_nr_mod_f1=(common.crear_df_iteraciones(historial, errores, "newton_raphson_mod")).set_index('iteracion')
df_nr_mod_f1
# Out:
#                          raiz               error              metodo
# iteracion
# 1          1.3333333333333333  0.3333333333333333  newton_raphson_mod
# 2          1.4117647058823528  0.0784313725490196  newton_raphson_mod
# 3          1.4142114384748701  0.0024467325925173  newton_raphson_mod
# 4          1.4142135623715002  0.0000021238966301  newton_raphson_mod

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_mod_f1.tail(1)
# Out:
#                          raiz               error              metodo
# iteracion
# 4          1.4142135623715002  0.0000021238966301  newton_raphson_mod

# %% [markdown]
# #### Secante, tolerancia 1e-13

# %%
historial, errores = metodo.secante(f1, 1e-13, 0.0,2.0)
df_sec_f1=(common.crear_df_iteraciones(historial, errores, "secante")).set_index('iteracion')
df_sec_f1
# Out:
#                          raiz               error   metodo
# iteracion
# 1          1.0000000000000000  1.0000000000000000  secante
# 2          2.0000000000000000  1.0000000000000000  secante
# 3          1.3333333333333335  0.6666666666666665  secante
# 4          1.4000000000000001  0.0666666666666667  secante
# 5          1.4146341463414633  0.0146341463414632  secante
# 6          1.4142114384748701  0.0004227078665933  secante
# 7          1.4142135620573204  0.0000021235824503  secante
# 8          1.4142135623730954  0.0000000003157750  secante
# 9          1.4142135623730951  0.0000000000000002  secante

# %% [markdown]
# Raiz encontrada:

# %%
df_sec_f1.tail(1)
# Out:
#                          raiz               error   metodo
# iteracion
# 9          1.4142135623730951  0.0000000000000002  secante

# %% [markdown]
# #### Secante, tolerancia 1e-5

# %%
historial, errores = metodo.secante(f1, 1e-5, 0.0,2.0)
df_sec_f1=(common.crear_df_iteraciones(historial, errores, "secante")).set_index('iteracion')
df_sec_f1
# Out:
#                          raiz               error   metodo
# iteracion
# 1          1.0000000000000000  1.0000000000000000  secante
# 2          2.0000000000000000  1.0000000000000000  secante
# 3          1.3333333333333335  0.6666666666666665  secante
# 4          1.4000000000000001  0.0666666666666667  secante
# 5          1.4146341463414633  0.0146341463414632  secante
# 6          1.4142114384748701  0.0004227078665933  secante
# 7          1.4142135620573204  0.0000021235824503  secante

# %% [markdown]
# Raiz encontrada:

# %%
df_sec_f1.tail(1)
# Out:
#                          raiz               error   metodo
# iteracion
# 7          1.4142135620573204  0.0000021235824503  secante

# %% [markdown]
# ### $ f_{2}(x) $

# %% [markdown]
# #### Biseccion, tolerancia 1e-13

# %%
historial, errores = metodo.biseccion(f2, 1e-13, 0.0, 2.0)
df_b_f2=(common.crear_df_iteraciones(historial, errores, "biseccion"))
df_b_f2 = df_b_f2[:5].append(df_b_f2[-5:]).set_index('iteracion')
df_b_f2
# Out:
#                          raiz               error     metodo
# iteracion
# 1          1.0000000000000000  0.5000000000000000  biseccion
# 2          1.5000000000000000  0.2500000000000000  biseccion
# 3          1.2500000000000000  0.1250000000000000  biseccion
# 4          1.1250000000000000  0.0625000000000000  biseccion
# 5          1.1875000000000000  0.0312500000000000  biseccion
# 14         1.2000732421875000  0.0000610351562500  biseccion
# 15         1.2000122070312500  0.0000305175781250  biseccion
# 16         1.1999816894531250  0.0000152587890625  biseccion
# 17         1.1999969482421875  0.0000076293945312  biseccion
# 18         1.2000045776367188  0.0000000000001000  biseccion

# %% [markdown]
# Raiz encontrada:

# %%
df_b_f2.tail(1)
# Out:
#                          raiz            error     metodo
# iteracion
# 18         1.2000045776367188  0.0000000000001  biseccion

# %% [markdown]
# #### Biseccion, tolerancia 1e-5

# %%
historial, errores = metodo.biseccion(f2, 1e-5, 0.0, 2.0)
df_b_f2=(common.crear_df_iteraciones(historial, errores, "biseccion"))
df_b_f2 = df_b_f2[:5].append(df_b_f2[-5:]).set_index('iteracion')
df_b_f2
# Out:
#                          raiz               error     metodo
# iteracion
# 1          1.0000000000000000  0.5000000000000000  biseccion
# 2          1.5000000000000000  0.2500000000000000  biseccion
# 3          1.2500000000000000  0.1250000000000000  biseccion
# 4          1.1250000000000000  0.0625000000000000  biseccion
# 5          1.1875000000000000  0.0312500000000000  biseccion
# 14         1.2000732421875000  0.0000610351562500  biseccion
# 15         1.2000122070312500  0.0000305175781250  biseccion
# 16         1.1999816894531250  0.0000152587890625  biseccion
# 17         1.1999969482421875  0.0000076293945312  biseccion
# 18         1.2000045776367188  0.0000100000000000  biseccion

# %% [markdown]
# Raiz encontrada:

# %%
df_b_f2.tail(1)
# Out:
#                          raiz    error     metodo
# iteracion
# 18         1.2000045776367188  0.00001  biseccion

# %% [markdown]
# #### Newton-Raphson, tolerancia 1e-13

# %%
historial, errores = metodo.newton_raphson(f2, 1e-13, 1.0)
df_nr_f2=(common.crear_df_iteraciones(historial, errores, "newton_raphson"))
df_nr_f2 = df_nr_f2[:5].append(df_nr_f2[-5:]).set_index('iteracion')
df_nr_f2
# Out:
#                          raiz               error          metodo
# iteracion
# 1          1.0670391061452542  0.0670391061452542  newton_raphson
# 2          1.1115008625849991  0.0444617564397449  newton_raphson
# 3          1.1410565672168191  0.0295557046318200  newton_raphson
# 4          1.1607272681472514  0.0196707009304322  newton_raphson
# 5          1.1738277683695260  0.0131005002222746  newton_raphson
# 31         1.2000217599883414  0.0000108238529835  newton_raphson
# 32         1.2000147669410757  0.0000069930472657  newton_raphson
# 33         1.2000107474905077  0.0000040194505679  newton_raphson
# 34         1.2000073749969029  0.0000033724936048  newton_raphson
# 35         1.2000073749969029  0.0000000000001000  newton_raphson

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_f2.tail(1)
# Out:
#                          raiz            error          metodo
# iteracion
# 35         1.2000073749969029  0.0000000000001  newton_raphson

# %% [markdown]
# #### Newton-Raphson, tolerancia 1e-5

# %%
historial, errores = metodo.newton_raphson(f2, 1e-5, 1.0)
df_nr_f2=(common.crear_df_iteraciones(historial, errores, "newton_raphson"))
df_nr_f2 = df_nr_f2[:5].append(df_nr_f2[-5:]).set_index('iteracion')
df_nr_f2
# Out:
#                          raiz               error          metodo
# iteracion
# 1          1.0670391061452542  0.0670391061452542  newton_raphson
# 2          1.1115008625849991  0.0444617564397449  newton_raphson
# 3          1.1410565672168191  0.0295557046318200  newton_raphson
# 4          1.1607272681472514  0.0196707009304322  newton_raphson
# 5          1.1738277683695260  0.0131005002222746  newton_raphson
# 19         1.1999104271123096  0.0000448096964709  newton_raphson
# 20         1.1999403113955580  0.0000298842832485  newton_raphson
# 21         1.1999602388486945  0.0000199274531365  newton_raphson
# 22         1.1999736678970567  0.0000134290483622  newton_raphson
# 23         1.1999826569716792  0.0000089890746224  newton_raphson

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_f2.tail(1)
# Out:
#                          raiz               error          metodo
# iteracion
# 23         1.1999826569716792  0.0000089890746224  newton_raphson

# %% [markdown]
# #### Newton-Raphson modificado, tolerancia 1e-13

# %%
historial, errores = metodo.newtonRaphsonMod(f2, 1e-13, 1.0)
df_nr_mod_f2=(common.crear_df_iteraciones(historial, errores, "newton_raphson_mod"))
df_nr_mod_f2 = df_nr_mod_f2[:5].append(df_nr_mod_f2[-5:]).set_index('iteracion')
df_nr_mod_f2
# Out:
#                          raiz               error              metodo
# iteracion
# 1          1.1984295612009492  0.1984295612009492  newton_raphson_mod
# 2          1.1999999589314381  0.0015703977304888  newton_raphson_mod
# 3          1.1999999399606254  0.0000000189708127  newton_raphson_mod
# 4          1.1999999123854459  0.0000000275751795  newton_raphson_mod
# 5          1.1999998712580215  0.0000000411274244  newton_raphson_mod
# 4          1.1999999123854459  0.0000000275751795  newton_raphson_mod
# 5          1.1999998712580215  0.0000000411274244  newton_raphson_mod
# 6          1.1999998077151541  0.0000000635428674  newton_raphson_mod
# 7          1.1999997119874051  0.0000000957277491  newton_raphson_mod
# 8          1.1999997119874051  0.0000000000001000  newton_raphson_mod

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_mod_f2.tail(1)
# Out:
#                          raiz            error              metodo
# iteracion
# 8          1.1999997119874051  0.0000000000001  newton_raphson_mod

# %% [markdown]
# #### Newton-Raphson modificado, tolerancia 1e-5

# %%
historial, errores = metodo.newtonRaphsonMod(f2, 1e-5, 1.0)
df_nr_mod_f2=(common.crear_df_iteraciones(historial, errores, "newton_raphson_mod")).set_index('iteracion')
#df_nr_mod_f2 = df_nr_mod_f2[:5].append(df_nr_mod_f2[-5:]).set_index('iteracion')
df_nr_mod_f2
# Out:
#                          raiz               error              metodo
# iteracion
# 1          1.1984295612009492  0.1984295612009492  newton_raphson_mod
# 2          1.1999999589314381  0.0015703977304888  newton_raphson_mod
# 3          1.1999999399606254  0.0000000189708127  newton_raphson_mod

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_mod_f2.tail(1)
# Out:
#                          raiz               error              metodo
# iteracion
# 3          1.1999999399606254  0.0000000189708127  newton_raphson_mod

# %% [markdown]
# #### Secante, tolerancia 1e-13

# %%
historial, errores = metodo.secante(f2, 1e-13, 0.0,2.0)
df_sec_f2=(common.crear_df_iteraciones(historial, errores, "secante"))
df_sec_f2 = df_sec_f2[:5].append(df_sec_f2[-5:]).set_index('iteracion')
df_sec_f2
# Out:
#                          raiz               error   metodo
# iteracion
# 1          1.4754098360655747  1.4754098360655747  secante
# 2          1.4538801420509524  0.0215296940146223  secante
# 3          1.3760856125859084  0.0777945294650439  secante
# 4          1.3371967591646468  0.0388888534212617  secante
# 5          1.3023532156576823  0.0348435435069645  secante
# 37         1.2000131768390607  0.0000039668386378  secante
# 38         1.2000100915201202  0.0000030853189406  secante
# 39         1.2000088573925440  0.0000012341275761  secante
# 40         1.2000076232649679  0.0000012341275761  secante
# 41         1.2000082403287560  0.0000006170637881  secante

# %% [markdown]
# Raiz encontrada:

# %%
df_sec_f2.tail(1)
# Out:
#                         raiz               error   metodo
# iteracion
# 41         1.200008240328756  0.0000006170637881  secante

# %% [markdown]
# #### Secante, tolerancia 1e-5

# %%
historial, errores = metodo.secante(f2, 1e-5, 0.0,2.0)
df_sec_f2=(common.crear_df_iteraciones(historial, errores, "secante"))
df_sec_f2 = df_sec_f2[:5].append(df_sec_f2[-5:]).set_index('iteracion')
df_sec_f2
# Out:
#                          raiz               error   metodo
# iteracion
# 1          1.4754098360655747  1.4754098360655747  secante
# 2          1.4538801420509524  0.0215296940146223  secante
# 3          1.3760856125859084  0.0777945294650439  secante
# 4          1.3371967591646468  0.0388888534212617  secante
# 5          1.3023532156576823  0.0348435435069645  secante
# 30         1.2000910822084438  0.0000295619717794  secante
# 31         1.2000687422730196  0.0000223399354242  secante
# 32         1.2000519419150786  0.0000168003579410  secante
# 33         1.2000392353152434  0.0000127065998352  secante
# 34         1.2000297749270450  0.0000094603881984  secante

# %% [markdown]
# Raiz encontrada:

# %%
df_sec_f2.tail(1)
# Out:
#                         raiz               error   metodo
# iteracion
# 34         1.200029774927045  0.0000094603881984  secante

# %% [markdown]
# ### $ f_{3}(x) $

# %% [markdown]
# #### Biseccion, tolerancia 1e-13

# %%
historial, errores = metodo.biseccion(f3, 1e-13, 0.0, 2.0)
df_b_f3=(common.crear_df_iteraciones(historial, errores, "biseccion")).set_index('iteracion')
df_b_f3
# Out:
#            raiz            error     metodo
# iteracion
# 1           1.0  0.5000000000000  biseccion
# 2           1.5  0.0000000000001  biseccion

# %% [markdown]
# Raiz encontrada:

# %%
df_b_f3.tail(1)
# Out:
#            raiz            error     metodo
# iteracion
# 2           1.5  0.0000000000001  biseccion

# %% [markdown]
# #### Biseccion, tolerancia 1e-5

# %%
historial, errores = metodo.biseccion(f3, 1e-5, 0.0, 2.0)
df_b_f3=(common.crear_df_iteraciones(historial, errores, "biseccion")).set_index('iteracion')
df_b_f3
# Out:
#            raiz    error     metodo
# iteracion
# 1           1.0  0.50000  biseccion
# 2           1.5  0.00001  biseccion

# %% [markdown]
# Raiz encontrada:

# %%
df_b_f3.tail(1)
# Out:
#            raiz    error     metodo
# iteracion
# 2           1.5  0.00001  biseccion

# %% [markdown]
# #### Newton-Raphson, tolerancia 1e-13

# %%
historial, errores = metodo.newton_raphson(f3, 1e-13, 1.4)
df_nr_f3=(common.crear_df_iteraciones(historial, errores, "newton_raphson")).set_index('iteracion')
#df_nr_f3 = df_nr_f3[:5].append(df_nr_f3[-5:]).set_index('iteracion')
df_nr_f3
# Out:
#                          raiz               error          metodo
# iteracion
# 1          1.5086956521739130  0.1086956521739131  newton_raphson
# 2          1.4999947366862836  0.0087009154876294  newton_raphson
# 3          1.5000000000000011  0.0000052633137175  newton_raphson
# 4          1.5000000000000000  0.0000000000000011  newton_raphson

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_f3.tail(1)
# Out:
#            raiz               error          metodo
# iteracion
# 4           1.5  0.0000000000000011  newton_raphson

# %% [markdown]
# #### Newton-Raphson, tolerancia 1e-5

# %%
historial, errores = metodo.newton_raphson(f3, 1e-5, 1.4)
df_nr_f3=(common.crear_df_iteraciones(historial, errores, "newton_raphson")).set_index('iteracion')
#df_nr_f3 = df_nr_f3[:5].append(df_nr_f3[-5:]).set_index('iteracion')
df_nr_f3
# Out:
#                          raiz               error          metodo
# iteracion
# 1          1.5086956521739130  0.1086956521739131  newton_raphson
# 2          1.4999947366862836  0.0087009154876294  newton_raphson
# 3          1.5000000000000011  0.0000052633137175  newton_raphson

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_f3.tail(1)
# Out:
#                          raiz               error          metodo
# iteracion
# 3          1.5000000000000011  0.0000052633137175  newton_raphson

# %% [markdown]
# #### Newton-Raphson modificado, tolerancia 1e-13

# %%
historial, errores = metodo.newtonRaphsonMod(f3, 1e-13, 1.4)
df_nr_mod_f3=(common.crear_df_iteraciones(historial, errores, "newton_raphson_mod")).set_index('iteracion')
#df_nr_mod_f2 = df_nr_mod_f2[:5].append(df_nr_mod_f2[-5:]).set_index('iteracion')
df_nr_mod_f3
# Out:
#                          raiz               error              metodo
# iteracion
# 1          1.4851851851851852  0.0851851851851853  newton_raphson_mod
# 2          1.4999480665964755  0.0147628814112903  newton_raphson_mod
# 3          1.4999999999977589  0.0000519334012834  newton_raphson_mod
# 4          1.5000000000000000  0.0000000000022411  newton_raphson_mod
# 5          1.5000000000000000  0.0000000000001000  newton_raphson_mod

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_mod_f3.tail(1)
# Out:
#            raiz            error              metodo
# iteracion
# 5           1.5  0.0000000000001  newton_raphson_mod

# %% [markdown]
# #### Newton-Raphson modificado, tolerancia 1e-5

# %%
historial, errores = metodo.newtonRaphsonMod(f3, 1e-5, 1.4)
df_nr_mod_f3=(common.crear_df_iteraciones(historial, errores, "newton_raphson_mod")).set_index('iteracion')
#df_nr_mod_f2 = df_nr_mod_f2[:5].append(df_nr_mod_f2[-5:]).set_index('iteracion')
df_nr_mod_f3
# Out:
#                          raiz               error              metodo
# iteracion
# 1          1.4851851851851852  0.0851851851851853  newton_raphson_mod
# 2          1.4999480665964755  0.0147628814112903  newton_raphson_mod
# 3          1.4999999999977589  0.0000519334012834  newton_raphson_mod
# 4          1.5000000000000000  0.0000000000022411  newton_raphson_mod

# %% [markdown]
# Raiz encontrada:

# %%
df_nr_mod_f3.tail(1)
# Out:
#            raiz               error              metodo
# iteracion
# 4           1.5  0.0000000000022411  newton_raphson_mod

# %% [markdown]
# #### Secante, tolerancia 1e-13

# %%
historial, errores = metodo.secante(f3, 1e-13, 1.1,2.0)
df_sec_f3=(common.crear_df_iteraciones(historial, errores, "secante"))
df_sec_f3 = df_sec_f3[:5].append(df_sec_f3[-5:]).set_index('iteracion')
df_sec_f3
# Out:
#                          raiz               error   metodo
# iteracion
# 1          1.5807447293293546  0.4807447293293545  secante
# 2          1.4501488517662675  0.1305958775630871  secante
# 3          1.5004983539847645  0.0503495022184970  secante
# 4          1.4999950716443982  0.0005032823403663  secante
# 5          1.5000000000048475  0.0000049283604493  secante
# 3          1.5004983539847645  0.0503495022184970  secante
# 4          1.4999950716443982  0.0005032823403663  secante
# 5          1.5000000000048475  0.0000049283604493  secante
# 6          1.5000000000000000  0.0000000000048475  secante
# 7          1.5000000000000000  0.0000000000001000  secante

# %% [markdown]
# Raiz encontrada:

# %%
df_sec_f3.tail(1)
# Out:
#            raiz            error   metodo
# iteracion
# 7           1.5  0.0000000000001  secante

# %% [markdown]
# #### Secante, tolerancia 1e-5

# %%
historial, errores = metodo.secante(f3, 1e-5, 1.1,2.0)
df_sec_f3=(common.crear_df_iteraciones(historial, errores, "secante")).set_index('iteracion')
#df_sec_f3 = df_sec_f3[:5].append(df_sec_f3[-5:]).set_index('iteracion')
df_sec_f3
# Out:
#                          raiz               error   metodo
# iteracion
# 1          1.5807447293293546  0.4807447293293545  secante
# 2          1.4501488517662675  0.1305958775630871  secante
# 3          1.5004983539847645  0.0503495022184970  secante
# 4          1.4999950716443982  0.0005032823403663  secante
# 5          1.5000000000048475  0.0000049283604493  secante

# %% [markdown]
# Raiz encontrada:

# %%
df_sec_f3.tail(1)
# Out:
#                          raiz               error   metodo
# iteracion
# 5          1.5000000000048475  0.0000049283604493  secante

# %% [markdown]
# (c) Halle la raı́z mediante la función de búsqueda de raı́ces de un lenguaje o paquete orientado a
# cálculo numérico (e.g. Python+SciPy: scipy.optimize.brentq).

# %% [markdown]
# ### $ f_{1}(x) $

# %%
optimize.brentq(f1.expresion, 0.0, 2.0)
# Out:
# 1.4142135623731364

# %% [markdown]
# ### $ f_{2}(x) $

# %%
optimize.brentq(f2.expresion, 0.0, 2.0)
# Out:
# 1.2000081652661798

# %% [markdown]
# ### $ f_{3}(x) $

# %%
optimize.brentq(f3.expresion, 0.0, 2.0)
# Out:
# 1.5000000000000198

# %% [markdown]
# (d) Compare los resultados obtenidos para los distintos métodos y cotas, grafique el orden de con-
# vergencia P y la constante asisntotica λ para todos los casos. Discuta ventajas y desventajas.
# ¿Son las que esperaba en base a la teorı́a?

# %% [markdown]
# ### $ f_{1}(x) $

# %% [markdown]
# Tolerancia 1e-13

# %%
common.graficar_errores(f1,1e-13,1.0,0.0,2.0)

# %% [markdown]
# Tolerancia 1e-5

# %%
common.graficar_errores(f1,1e-5,1.0,0.0,2.0)

# %%
common.obtener_graficos_orden_de_convergencia(f1)

# %% [markdown]
# ### $ f_{2}(x) $

# %% [markdown]
# Tolerancia 1e-13

# %%
common.graficar_errores(f1,1e-13,1.0,0.0,2.0)

# %% [markdown]
# Tolerancia 1e-5

# %%
common.graficar_errores(f1,1e-5,1.0,0.0,2.0)

# %%
common.obtener_graficos_orden_de_convergencia(f2)

# %% [markdown]
# ### $ f_{3}(x) $

# %% [markdown]
# Tolerancia 1e-13

# %%
common.graficar_errores(f3,1e-13,1.4,1.1,2.0)

# %% [markdown]
# Tolerancia 1e-5

# %%
common.graficar_errores(f3,1e-5,1.4,1.1,2.0)

# %%
common.obtener_graficos_orden_de_convergencia(f3)
